# %% [markdown]
# # Clean the data set step by step

# %%
import numpy as np
import pandas as pd
import re
from dateutil.parser import parse
import warnings

# %%
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../data/attacks.csv", encoding='latin1')

# %%
# rename columns
df.rename(columns={'Sex ':'Sex', 'Species ':'Species'}, inplace=True)

# %%
# no data from 6302 on
df = df.drop(df.index[6302:])

# %%
# drop duplicated
df.drop([4688, 5709, 6295], inplace=True)

# %%
# unique values for the identifier column
df['Case Number'] = [int(e) for e in range(1, len(df)+1)]

# %%
# case number is date till row 6300
df.loc[0:6300, 'Date'] = df.loc[0:6300, 'Case Number.1']

# kepp only the wanted characters
df['Date'] = df['Date'].str.extract('^(\d{4}\.\d{2}\.\d{2})', expand=False)

# rest is unknown
df.loc[6177:, 'Date'] = 'unknown'

# %%
# years have '.0' at the end
df['Year'] = df['Year'].astype(str).replace(to_replace=r'\.0', value='', regex=True)

# Replace years that are not 4 digits with NaN
df['Year'] = df['Year'].apply(lambda x: x if len(str(x)) == 4 else np.nan)

# Convert to numeric, making non-numeric values NaN
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Cast into integer
df['Year'] = df['Year'].astype('Int64')

#importany: years go from 1543 to 2018
df['Year'].min()
# Out:
# 1543

# %%
# null is 'unknown'
df['Type'].fillna('unknown', inplace=True)
# invalid is unknown
df['Type'] = df['Type'].replace(to_replace='Invalid', value='unknown', regex=True)

# standarize boating
df['Type'] = df['Type'].replace(to_replace='Boat', value='Boating')
df['Type'] = df['Type'].replace(to_replace='Boatomg', value='Boating')

# %%
#too many unique values
df['Species'].fillna('unknown', inplace=True)
df['Investigator or Source'].fillna('unknown', inplace=True)

# %%
# clean countries
df['Country'] = df['Country'].str.capitalize()

df['Country'].replace({'St helena, british overseas territory': 'British overseas territory',
  'Diego garcia': 'unknown', 
  'Turks & caicos': 'Turkish islands and caicos',
  'United arab emirates (uae)': 'United arab emirates',
  'British virgin islands': 'British overseas territory',
  'Grand cayman': 'Caiman Islands',
  'Mexico ': 'Mexico',
  ' tonga': 'Tonga',
  'Egypt / israel': 'Egypt',
  'British isles': 'British overseas territory',
  'Federated states of micronesia': 'Micronesia',
  'Admiralty islands': 'Papua New Guinea',
  'Red sea / indian ocean': 'Read sea',
  'Andaman / nicobar islandas': 'Andaman and nicobar islands',
  'Sudan?': 'Sudan',
  'Iran / iraq': 'Iran',
  ' philippines': 'Philippines',
  'Solomon islands / vanuatu': 'Solomon islands',
  'Southwest pacific ocean': 'South pacific ocean',
  'Mid-pacifc ocean': 'Mid pacifc ocean',
  'Italy / croatia': 'Italy',
  'San domingo': 'Dominican republic',
  'Crete': 'Greece',
  'Egypt ': 'Egypt',
  'British new guinea': 'Papua New Guinea',
  'Ocean': 'unknown',
  'Indian ocean?': 'Indian ocean',
  'Andaman islands': 'Andaman and nicobar islands',
  'Equatorial guinea / cameroon': 'Equatorial guinea',
  'Africa': 'unknown',                    
  'Coast of africa': 'unknown',
  'Between portugal & india': 'unknown',
  'Red sea?': 'Read sea',
  'Asia?': 'unknown',
  'Ceylon (sri lanka)': 'Ceylon'
  }, inplace=True)

df['Country'].fillna('unknown', inplace=True)

# %%
#too many unique values
df['Area'] = df['Area'].str.capitalize()

df['Area'].fillna('unknown', inplace=True)

# %%
df.query("Country == 'unknown' & Area != 'unknown'")
# Out:
#       Case Number        Date  Year          Type  Country  \
# 2956         2957  1983.00.00  1983    Unprovoked  unknown
# 3387         3388  1970.08.02  1970       unknown  unknown
# 4018         4019  1960.01.26  1960  Sea Disaster  unknown
# 4231         4232  1956.09.13  1956    Unprovoked  unknown
# 4266         4267  1956.00.00  1956  Sea Disaster  unknown
# 4498         4499  1949.12.00  1949  Sea Disaster  unknown
# 4700         4700  1942.11.00  1942  Sea Disaster  unknown
# 4712         4712  1942.06.00  1942    Unprovoked  unknown
# 5020         5020  1931.04.27  1931    Unprovoked  unknown
# 5612         5612  1897.03.15  1897    Unprovoked  unknown
# 5742         5741  1887.07.30  1887  Sea Disaster  unknown
# 5748         5747  1887.00.00  1887  Sea Disaster  unknown
# 5808         5807  1881.08.16  1881    Unprovoked  unknown
# 6059         6058  1844.05.24  1844    Unprovoked  unknown
# 6137         6136  1787.07.05  1787    Unprovoked  unknown
# 6175         6174  0077.00.00  <NA>    Unprovoked  unknown
# 6177         6176     unknown  <NA>    Unprovoked  unknown
#
#                                                  Area  \
# 2956                                  English channel
# 3387                                    Caribbean sea
# 4018                Between timor & darwin, australia
# 4231               Near the andaman & nicobar islands
# 4266                     Between comores & madagascar
# 4498                                    Caribbean sea
# 4700                         Off south american coast
# 4712    300 miles east of st. thomas (virgin islands)
# 5020                      French southern territories
# 5612                                Mediterranean sea
# 5742                               Gulf of california
# 5748  Somewhere between philadelphia and hiogo, japan
# 5808                                    Western banks
# 6059                             Island of st. thomas
# 6137                                        St helena
# 6175                                       Ionian sea
# 6177                                       Ionian sea
#
#                          Location  \
# 2956                          NaN
# 3387    Between St. Kitts & Nevis
# 4018                          NaN
# 4231                          NaN
# 4266                  Geyser Bank
# 4498  Between  Cuba  & Costa Rica
# 4700                          NaN
# 4712                          NaN
# 5020               Île Saint-Paul
# 5612                          NaN
# 5742                          NaN
# 5748                          NaN
# 5808                          NaN
# 6059                          NaN
# 6137                Landing Place
# 6175                          NaN
# 6177                          NaN
#
#                                                Activity  \
# 2956                                           Swimming
# 3387        Sea Disaster Sinking of ferryboat Christina
# 4018  Portuguese Airliner with 9 people aboard went ...
# 4231                              Climbing back on ship
# 4266                                          Shipwreck
# 4498     Sea Disaster, sinking of the motorship Wingate
# 4700  Dutch merchant ship Zaandam torpedoed  by the ...
# 4712  On life raft tethered to lifeboat. A seaman pu...
# 5020                             Fishing, boat capsized
# 5612                                           Swimming
# 5742              Sea disaster, wreck of the sloop Sara
# 5748  British ship Macedon was thrown on her beam en...
# 5808  Floating, holding onto an oar after dory capsized
# 6059                                     Fell overboard
# 6137                                           Swimming
# 6175                                      Sponge diving
# 6177                              Ascending from a dive
#
#                                                   Name  Sex  Age  \
# 2956                Padma Shri Taranath Narayan Shenoy    M  NaN
# 3387                                               NaN  NaN  NaN
# 4018                                               NaN  NaN  NaN
# 4231                                              male    M  NaN
# 4266  Captain Eric Hunt, the cook & a French passenger    M  NaN
# 4498               Albert Battles, James Dean & 4 crew    M  NaN
# 4700                                               NaN    M  NaN
# 4712                                              male    M  NaN
# 5020                                         Quillezic    M  NaN
# 5612                                              male    M  NaN
# 5742                                           2 males    M  NaN
# 5748                                  a ship's steward    M  NaN
# 5808                                   George Sedgwick    M   20
# 6059              Martin, coxswain of the USS Saratoga    M  NaN
# 6137                            Private Isaac Hicksled    M  NaN
# 6175                                             males    M  NaN
# 6177                           Tharsys, a sponge diver    M  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 2956                                    Left leg bitten           N
# 3387  Sharks scavenged on bodies, but no record of t...         NaN
# 4018  As searchers approached wreckage, sharks circl...           N
# 4231                                              FATAL           Y
# 4266                                              FATAL           Y
# 4498                    Fatal or drowning or scavenging           Y
# 4700                                              FATAL           Y
# 4712                                  Forearm lacerated           N
# 5020                                              FATAL           Y
# 5612                                              FATAL           Y
# 5742                                              FATAL           Y
# 5748                                       Foot severed           N
# 5808                                              FATAL           Y
# 6059                                              FATAL           Y
# 6137                                              FATAL           Y
# 6175                                              FATAL           Y
# 6177                      FATAL, shark/s bit him in two           Y
#
#            Time                                            Species  \
# 2956        NaN                                            unknown
# 3387  Afternoon  Shark involvement prior to death was not confi...
# 4018        NaN                                            unknown
# 4231       P.M.                                         Blue shark
# 4266        NaN                                            unknown
# 4498        NaN                    Shark involvement not confirmed
# 4700        NaN                                            unknown
# 4712        NaN                                            unknown
# 5020        NaN                                            unknown
# 5612        NaN                                            unknown
# 5742        NaN                                            unknown
# 5748        NaN                                            unknown
# 5808        NaN                                            unknown
# 6059        NaN                                            unknown
# 6137        NaN                                            unknown
# 6175        NaN                                            unknown
# 6177        NaN                                            unknown
#
#                                  Investigator or Source  \
# 2956                           Times of India, 2/5/2012
# 3387                        Rome News Tribune, 8/3/1970
# 4018                       V.M. Coppleson (1962), p.260
# 4231                                          M. Hosina
# 4266                                       dinofish.com
# 4498                           Canberra Times, 1/6/1950
# 4700      M.  Murphy; V.M. Coppleson (1962), pp.207-208
# 4712                       V.M. Coppleson (1962), p.258
# 5020                       Los Angeles Times, 4/27/1931
# 5612                      Daily Northwestern, 5/15/1897
# 5742                 Austin Weekly Statesman, 8/11/1887
# 5748                    Galveston Daily News, 2/11/1888
# 5808                Lewiston Evening Journal, 8/16/1881
# 6059                            Tioga Eagle, 7/31/1844
# 6137  H.R. Janisch (1885), Extracts from the St. Hel...
# 6175  Perils mentioned by Pliny the Elder (23 A.D. t...
# 6177  Reported by Greek poet, Leonidas of Tarentum (...
#
#                                      pdf  \
# 2956             1983.00.00.d-Shenoy.pdf
# 3387  1970.08.02-Christina-ferryboat.pdf
# 4018  1960.01.26-Portuguese airliner.pdf
# 4231             1956.09.13-TunaBoat.pdf
# 4266          1956.00.00.g-Capt-Hunt.pdf
# 4498            1949.12.00.b-Wingate.pdf
# 4700               1942.11.00.a-Izzi.pdf
# 4712         1942.06.00-on-life-raft.pdf
# 5020          1931.04.27.R-Quillezic.pdf
# 5612    1897.03.15.b.R-Mediterranean.pdf
# 5742              1887.07.30-TheSara.pdf
# 5748              1887.00.00-Macedom.pdf
# 5808           1881.08.16.R-Sedgwick.pdf
# 6059             1844.05.24-Saratoga.pdf
# 6137             1787.07.05-Hicksled.pdf
# 6175                      77AD-Pliny.pdf
# 6177                   214BC-Tharsys.pdf
#
#                                            href formula  \
# 2956  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3387  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4018  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4231  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4266  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4498  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4700  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4712  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5020  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5612  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5742  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5748  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5808  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6059  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6137  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6175  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6177  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   Case Number.1  \
# 2956  http://sharkattackfile.net/spreadsheets/pdf_di...    1983.00.00.d
# 3387  http://sharkattackfile.net/spreadsheets/pdf_di...      1970.08.02
# 4018  http://sharkattackfile.net/spreadsheets/pdf_di...      1960.01.26
# 4231  http://sharkattackfile.net/spreadsheets/pdf_di...      1956.09.13
# 4266  http://sharkattackfile.net/spreadsheets/pdf_di...    1956.00.00.g
# 4498  http://sharkattackfile.net/spreadsheets/pdf_di...    1949.12.00.b
# 4700  http://sharkattackfile.net/spreadsheets/pdf_di...    1942.11.00.a
# 4712  http://sharkattackfile.net/spreadsheets/pdf_di...      1942.06.00
# 5020  http://sharkattackfile.net/spreadsheets/pdf_di...    1931.04.27.R
# 5612  http://sharkattackfile.net/spreadsheets/pdf_di...  1897.03.15.b.R
# 5742  http://sharkattackfile.net/spreadsheets/pdf_di...      1887.07.30
# 5748  http://sharkattackfile.net/spreadsheets/pdf_di...      1887.00.00
# 5808  http://sharkattackfile.net/spreadsheets/pdf_di...    1881.08.16.R
# 6059  http://sharkattackfile.net/spreadsheets/pdf_di...      1844.05.24
# 6137  http://sharkattackfile.net/spreadsheets/pdf_di...      1787.07.05
# 6175  http://sharkattackfile.net/spreadsheets/pdf_di...      0077.00.00
# 6177  http://sharkattackfile.net/spreadsheets/pdf_di...       0000.0214
#
#        Case Number.2  original order Unnamed: 22 Unnamed: 23
# 2956    1983.00.00.d          3347.0         NaN         NaN
# 3387      1970.08.02          2916.0         NaN         NaN
# 4018      1960.01.26          2285.0         NaN         NaN
# 4231      1956.09.13          2072.0         NaN         NaN
# 4266    1956.00.00.g          2037.0         NaN         NaN
# 4498    1949.12.00.b          1805.0         NaN         NaN
# 4700    1942.11.00.a          1603.0         NaN         NaN
# 4712      1942.06.00          1591.0         NaN         NaN
# 5020    1931.04.27.R          1283.0         NaN         NaN
# 5612  1897.03.15.b.R           691.0         NaN         NaN
# 5742      1887.07.30           561.0         NaN         NaN
# 5748      1887.00.00           555.0         NaN         NaN
# 5808    1881.08.16.R           495.0         NaN         NaN
# 6059      1844.05.24           244.0         NaN         NaN
# 6137      1787.07.05           166.0         NaN         NaN
# 6175      0077.00.00           128.0         NaN         NaN
# 6177       0000.0214           126.0         NaN         NaN

# %%
# countreis that can be deduced from the area as shown above
nuevos_valores = {2956: 'English channel',
  3387: 'Caribbean sea',
  4018: 'Australia',
  4231: 'Andaman and nicobar islands',
  4266: 'Madagascar',
  4498: 'Caribbean sea',
  4712: 'Caribbean sea',
  5020: 'Indian ocean',
  5612: 'Mediterranean sea',
  5742: 'Mexico',
  5748: 'Northern pacific ocean',
  6059: 'Caribbean sea',
  6137: 'Middle atlantic ocean',
  6175: 'Ionian sea',
  6177: 'Ionian sea',              
  }

df['Country'].update(pd.Series(nuevos_valores))

# %%
#too many unique values
df['Location'] = df['Location'].str.capitalize()

df['Location'].fillna('unknown', inplace=True)

# %%
# too many unique values
df['Activity'].fillna('Activity', inplace=True)

# %%
df.Sex.fillna('unknown', inplace=True)

df.Sex.replace({'M ': 'M',
  'lli': 'unknown', 
  'N': 'unknown',
  '.': 'unknown'
  }, inplace=True)

# %%
df['Name'].fillna('unknown', inplace=True)

df['Name'].replace({'Unknown': 'unknown'} , inplace=True)

# %%
df.Sex.fillna('unknown', inplace=True)

df.Sex.replace({'M ': 'M',
  'lli': 'unknown', 
  'N': 'unknown',
  '.': 'unknown'
  }, inplace=True)

# %%
df.query("Sex == 'unknown' & Name != 'unknown'")
# Out:
#       Case Number        Date  Year          Type     Country  \
# 59             60  2017.11.25  2017  Sea Disaster       Libya
# 179           180  2017.02.01  2017       Boating         Usa
# 218           219  2016.09.15  2016       Boating   Australia
# 243           244  2016.07.17  2016       Boating         Usa
# 326           327  2015.12.13  2015       Boating   Australia
# ...           ...         ...   ...           ...         ...
# 6167         6166  1617.00.00  1617    Unprovoked       India
# 6202         6201     unknown  <NA>    Unprovoked    Djibouti
# 6212         6211     unknown  <NA>       Boating  Mozambique
# 6259         6258     unknown  <NA>  Sea Disaster     unknown
# 6287         6286     unknown  <NA>    Unprovoked        Fiji
#
#                     Area                  Location  \
# 59               unknown            gars garabulli
# 179       South carolina  16 miles off hilton head
# 218    Western australia                   Bunbury
# 243              Alabama        8 miles off mobile
# 326      New south wales            Lake macquarie
# ...                  ...                       ...
# 6167         West bengal              Ganges delta
# 6202    Gulf of tadjoura                   unknown
# 6212  Inhambane province             Off inhambane
# 6259             unknown                   unknown
# 6287        Moala island                   unknown
#
#                                         Activity  \
# 59                              2 boats capsized
# 179                               Tagging sharks
# 218                                      Fishing
# 243        Fishing in Alabama Deep Fishing Rodeo
# 326                                      Fishing
# ...                                          ...
# 6167                                    Activity
# 6202                             A dhow capsized
# 6212                                     Fishing
# 6259  A group of survivors on a raft for 17-days
# 6287        Wreck of  large double sailing canoe
#
#                                                    Name      Sex  Age  \
# 59                                          31 migrants  unknown  NaN
# 179                               Chip Michelove & crew  unknown  NaN
# 218                              Occupant: Ben Stratton  unknown  NaN
# 243                                Occupant: Ben Raines  unknown  NaN
# 326         6 m boat: occupants  Stephen & Andrew Crust  unknown  NaN
# ...                                                 ...      ...  ...
# 6167                                      Indian people  unknown  NaN
# 6202                                   Passenger & crew  unknown  NaN
# 6212  4.8-metre skiboat, Occupants: Rod Salm & 4 fri...  unknown  NaN
# 6259                                                 C.  unknown  NaN
# 6287                                         20 Fijians  unknown  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 59                                                FATAL           Y
# 179              Shark bit boat, no injury to occupants           N
# 218            Shark rammed boat. No injury to occupant           N
# 243                 No injury, shark bit trolling motor           N
# 326            No injury, shark rammed boat & bit motor           N
# ...                                                 ...         ...
# 6167                                                NaN     UNKNOWN
# 6202                                              FATAL           Y
# 6212          No injury to occupants, shark bumped boat           N
# 6259  FATAL, shark leapt into raft and bit the man w...           Y
# 6287  FATAL, 18 people  were killed by sharks, 2 sur...           Y
#
#                 Time                                            Species  \
# 59               NaN  Some drowned but other may have been killed by...
# 179              NaN                           White shark, female, 14'
# 218              NaN                                            unknown
# 243              NaN                                  Tiger shark, 10'
# 326            10h30                                 White shark, 3.5 m
# ...              ...                                                ...
# 6167             NaN                                            unknown
# 6202             NaN                                            unknown
# 6212             NaN                                        Whale shark
# 6259  Late afternoon                                   1.2 m [4'] shark
# 6287             NaN                                            unknown
#
#                                  Investigator or Source  \
# 59                                TG Com 24, 11/25/2017
# 179                                   YouTube, 2/2/2017
# 218                          West Australian, 9/15/2016
# 243                                   Al.com, 7/19/2016
# 326                            Courier Mail, 12/15/2015
# ...                                                 ...
# 6167            H. Edwards, p.31, citing Samuel Purchas
# 6202                                        A. C. Doyle
# 6212                    South African Shark Attack File
# 6259         G.A. Llano in Airmen Against the Sea, p.69
# 6287  Fijian Society papers presented April 17, 1918...
#
#                                pdf  \
# 59          2017.11.25.R-Libya.pdf
# 179          2017.02.01.b-Boat.pdf
# 218          2016.09.15.R-boat.pdf
# 243            2016.07.17-Gulf.pdf
# 326      2015.12.13-Crust-Boat.pdf
# ...                            ...
# 6167        1617.00.00-Purchas.pdf
# 6202  ND-0119-Gulf-of-Tadjoura.pdf
# 6212         ND-0107-Inhambane.pdf
# 6259                 ND-0044-C.pdf
# 6287       ND-0015-FijianCanoe.pdf
#
#                                            href formula  \
# 59    http://sharkattackfile.net/spreadsheets/pdf_di...
# 179   http://sharkattackfile.net/spreadsheets/pdf_di...
# 218   http://sharkattackfile.net/spreadsheets/pdf_di...
# 243   http://sharkattackfile.net/spreadsheets/pdf_di...
# 326   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6167  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6202  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6212  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6259  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6287  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 59    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.11.25.R
# 179   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.02.01.b
# 218   http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.15.R
# 243   http://sharkattackfile.net/spreadsheets/pdf_di...    2016.07.17
# 326   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.12.13
# ...                                                 ...           ...
# 6167  http://sharkattackfile.net/spreadsheets/pdf_di...  1617.00.00.R
# 6202  http://sharkattackfile.net/spreadsheets/pdf_di...       ND-0119
# 6212  http://sharkattackfile.net/spreadsheets/pdf_di...       ND-0107
# 6259  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0044
# 6287  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0015
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23
# 59    2017.11.25.R          6244.0         NaN         NaN
# 179   2017.02.01.b          6124.0         NaN         NaN
# 218   2016.09.15.R          6085.0         NaN         NaN
# 243     2016.07.17          6060.0         NaN         NaN
# 326     2015.12.13          5977.0         NaN         NaN
# ...            ...             ...         ...         ...
# 6167  1617.00.00.R           136.0         NaN         NaN
# 6202       ND-0119           101.0         NaN         NaN
# 6212       ND-0107            91.0         NaN         NaN
# 6259       ND.0044            44.0         NaN         NaN
# 6287       ND.0015            16.0         NaN         NaN
#
# [418 rows x 24 columns]

# %%
# gender can be deduced by the name
nuevos_valores_area = {218: 'M',
  243: 'M',
  463: 'M', 
  465: 'M',
  747: 'M',
  820: 'M', 
  839: 'M',
  1177: 'M',
  1366: 'M', 
  1525: 'F',
  1624: 'M',
  2225: 'M', 
  2246: 'M',
  2273: 'M',
  2279: 'M', 
  2295: 'M',
  2317: 'M',
  2452: 'F', 
  2472: 'M',
  2478: 'M',
  2502: 'M', 
  2505: 'M',
  2799: 'M',
  2865: 'M', 
  3049: 'M',
  3157: 'M',
  3162: 'M', 
  3235: 'M',
  3306: 'M',
  3452: 'M', 
  3487: 'M',
  3704: 'M',
  3768: 'M', 
  3855: 'M',
  4036: 'F',
  4338: 'M', 
  4403: 'M',
  4467: 'M',
  4839: 'M', 
  5499: 'M',
  5602: 'M',
  6108: 'M', 
  6131: 'M',
  }
df['Sex'].update(pd.Series(nuevos_valores_area))

# %%
#ages to be deduced teens will be 17 years old. When there are more than one number it will be the mean
""" '18 months', '53', '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
'12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
'8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½', '21 & ?', '75',
'33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
'20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
'18 to 22', 'adult', '9 & 12', '? & 19', '9 months', '25 to 35',
'23 & 26', '1', '(adult)', '33 & 37', '25 or 28',
'37, 67, 35, 27,  ? & 27', '21, 34,24 & 35', '30 & 32', '50 & 30',
'17 & 35', 'X', '"middle-age"', '13 or 18', '34 & 19', '33 & 26',
'2 to 3 months', 'MAKE LINE GREEN', ' 43', '81', '"young"',
'7 or 8', '78', '17 & 16', 'F', 'Both 11', '9 or 10', 'young',
'36 & 23', '  ', 'A.M.', '?    &   14', '10 or 12', '31 or 33',
'2½', '13 or 14' """
# Out:
# ' \'18 months\', \'53\', \'30s\', \'50s\', \'teen\', \'77\', \'74\', \'28 & 26\', \'5\', \'86\', \'18 or 20\',\n\'12 or 13\', \'46 & 34\', \'28, 23 & 30\', \'Teens\', \'36 & 26\',\n\'8 or 10\', \'84\', \'\xa0 \', \' \', \'30 or 36\', \'6½\', \'21 & ?\', \'75\',\n\'33 or 37\', \'mid-30s\', \'23 & 20\', \' 30\', \'7      &    31\', \' 28\',\n\'20?\', "60\'s", \'32 & 30\', \'16 to 18\', \'87\', \'67\', \'Elderly\',\n\'mid-20s\', \'Ca. 33\', \'74 \', \'45 \', \'21 or 26\', \'20 \', \'>50\',\n\'18 to 22\', \'adult\', \'9 & 12\', \'? & 19\', \'9 months\', \'25 to 35\',\n\'23 & 26\', \'1\', \'(adult)\', \'33 & 37\', \'25 or 28\',\n\'37, 67, 35, 27,  ? & 27\', \'21, 34,24 & 35\', \'30 & 32\', \'50 & 30\',\n\'17 & 35\', \'X\', \'"middle-age"\', \'13 or 18\', \'34 & 19\', \'33 & 26\',\n\'2 to 3 months\', \'MAKE LINE GREEN\', \' 43\', \'81\', \'"young"\',\n\'7 or 8\', \'78\', \'17 & 16\', \'F\', \'Both 11\', \'9 or 10\', \'young\',\n\'36 & 23\', \'  \', \'A.M.\', \'?    &   14\', \'10 or 12\', \'31 or 33\',\n\'2½\', \'13 or 14\' '

# %%
df.Age.replace({ '18 months': '1', 
  '30s': '35',
  '50s': '50',
  'teen ': '16',
  '18 or 20': '19', 
  '12 or 13': '12',
  '28 23  30': '28',
  'Teens ': '16',
  '36  26': '31', 
  '8 or 10': '9',
  '\xa0 ': 'nan',
  '  ': 'nan',
  '30 or 36': '33', 
  '6½': '6',
  '21  ': '21',
  '33 or 37': '35',
  'mid30s': '35',
  '23  20': '21',
  ' 30': '30', 
  '7          31': 'nan',
  ' 28': '28',
  '32  30': '31',
  '16 to 18': '17', 
  'Elderly': '65',
  'mid20s': '25',
  'Ca 33': '33',
  '74 ': '74',
  '45 ': '45', 
  '21 or 26': '23',
  '20 ': '20',
  '18 to 22': '20',
  'adult': '42',
  '9  12': '10',
  '   19': '19', 
  '9 months': '0',
  ' 25 to 35': '30',
  '23  26': '24',
  '33  37': '35',
  '25 or 28': '26',
  '37 67 35 27    27': '38',
  '21 3424  35': '28',
  '30  32': '31',
  '50  30': '40',
  '17  35': '26',
  'X': 'nan',
  'middleage': '50',
  '13 or 18': '15', 
  '34  19': '26',
  '33  26': '29',
  '2 to 3 months': '0',
  'MAKE LINE GREEN': 'nan', 
  ' 43': '43',
  'young': '3',
  '7 or 8': '7',
  '17  16': '16',
  'F': 'nan',
  'Both 11': '11', 
  '9 or 10': '9',
  '36  23': '29',
  '  ': 'nan',
  'AM': 'nan', 
  '       14': '14',
  '10 or 12': '11',    
  '31 or 33': '32',
  '2½': '2',
  '13 or 14': '13',   
  '40s': '45',
  'Teen': 'nan',
  '60s': '60',
  'teen': 'nan',
  'Teens': 'nan',
  ' ': 'nan',
  '  19': '19',
  '25 to 35': '30'
}, inplace=True)

# %%
# Remove non-numeric characters from the 'Age' column and convert to numeric, setting errors='coerce'
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# Finally, convert the column to integers
df['Age'] = df['Age'].astype('Int64')

# %%
# too many unique values
df.Injury.fillna('unknown', inplace=True)

# %%
df['Fatal (Y/N)'].fillna('unknown', inplace=True)

df['Fatal (Y/N)'].replace({'M': 'N',
  'UNKNOWN': 'unknown', 
  '2017': 'unknown',
  ' N': 'N',
  'N ': 'N',
  'y': 'Y'
}, inplace=True)

# %%
""" 
def is_valid_date(date_str):
    if isinstance(date_str, str):
        try:
            parser.parse(date_str)
            return True
        except ValueError:
            return False
    return False

# Use the function to replace invalid dates with 'unknown'
df['Date'] = df['Date'].apply(lambda x: x if is_valid_date(x) else 'unknown') """
# Out:
# " \ndef is_valid_date(date_str):\n    if isinstance(date_str, str):\n        try:\n            parser.parse(date_str)\n            return True\n        except ValueError:\n            return False\n    return False\n\n# Use the function to replace invalid dates with 'unknown'\ndf['Date'] = df['Date'].apply(lambda x: x if is_valid_date(x) else 'unknown') "

# %%
df.sample()
# Out:
#       Case Number        Date  Year        Type    Country             Area  \
# 2146         2147  1998.12.22  1998  Unprovoked  Australia  South australia
#
#              Location  Activity           Name Sex  Age  \
# 2146  Middleton beach  Standing  Megan O'Leary   F   21
#
#                              Injury Fatal (Y/N)   Time  Species  \
# 2146  2 puncture wounds in left leg           N  15h30  unknown
#
#                                  Investigator or Source  \
# 2146  The Advertiser, 12/23/1998, p.3; Daily Telegra...
#
#                          pdf  \
# 2146  1998.12.22-O'Leary.pdf
#
#                                            href formula  \
# 2146  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 2146  http://sharkattackfile.net/spreadsheets/pdf_di...    1998.12.22
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23
# 2146    1998.12.22          4157.0         NaN         NaN

# %%
columns_to_drop = ['href formula', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23']
df = df.drop(columns=columns_to_drop)

# %%
df.sample()
# Out:
#       Case Number        Date  Year        Type Country    Area  \
# 2606         2607  1991.02.24  1991  Unprovoked     Usa  Oregon
#
#                         Location Activity              Name Sex  Age  \
# 2606  Neskowin, tillamook county  Surfing  Tony Franciscone   M   38
#
#                              Injury Fatal (Y/N)   Time  \
# 2606  Calf lacerated & board bitten           N  09h30
#
#                       Species  Investigator or Source  \
# 2606  5.5 m [18'] white shark  R. Collier, pp.122-123
#
#                                      pdf  \
# 2606  1991.02.24-Franciscone_Collier.pdf
#
#                                                    href
# 2606  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
df.sample()
# Out:
#      Case Number        Date  Year        Type Country        Area  \
# 638          639  2013.08.17  2013  Unprovoked     Usa  California
#
#                                           Location Activity           Name  \
# 638  Pillar point, half-moon bay, san mateo county  Surfing  Wendi Zuccaro
#
#     Sex   Age                             Injury Fatal (Y/N)   Time  \
# 638   F  <NA>  No injury, shark bumped surfboard           N  12h40
#
#          Species Investigator or Source                     pdf  \
# 638  White shark             R. Collier  2013.08.17-Zaccaro.pdf
#
#                                                   href
# 638  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
activity_patterns = {
  'Drinking': r'\bdrink|\bdrunk|\balcohol|\bparty\b',
  'Surfing': r'\bsurf|\bboard|\bpaddle|\bpaddling\b',
  'Diving': r'\bdive|diving|snorkel\b',
  'Swimming': r'\bswim|beach|bath\b',
  'Fishing': r'\bfish\b',
  'Boating': r'\bboat|\boverboard|\bship|\bsail|\bferry|\bwreck',
  'Kayaking': r'\bkayak\b',
}

def categorize_activity(activity):
  if pd.isna(activity):
    return 'unknown'
  if 'overboard' in activity or 'Overboard' in activity:
    return 'Boating'
  for category, pattern in activity_patterns.items():
    if re.search(pattern, activity, re.IGNORECASE):
      return category
  return 'unknown'

df['Activity'] = df['Activity'].apply(categorize_activity)
df['Activity'].unique()
# Out:
# array(['Surfing', 'unknown', 'Diving', 'Swimming', 'Kayaking', 'Fishing',
#        'Boating'], dtype=object)

# %%
import pandas as pd
import re

def clean_and_standardize_time(time_str):
    if pd.isna(time_str) or time_str == 'unknown':
        return 'unknown'

    time_str = str(time_str).strip().lower()
    
    # Handle known specific patterns
    if re.match(r'\d{2}h\d{2}', time_str):
        return re.sub(r'(\d{2})h(\d{2})', r'\1:\2', time_str)[:5]  # Return the first 5 characters
    
    # Handle 'Morning' and 'Night'
    if 'morning' in time_str:
        return '08:00'[:5]  # Return the first 5 characters
    if 'night' in time_str:
        return '20:00'[:5]  # Return the first 5 characters
    
    # Handle 'Shortly before' entries
    if 'shortly before' in time_str or 'just before' in time_str:
        # Extract the hour from the entry, e.g., '12h00'
        match = re.search(r'(\d{2})h(\d{2})', time_str)
        if match:
            return f"{match.group(1)}:{match.group(2)}"[:5]  # Return the first 5 characters
    
    # Handle ranges
    if re.match(r'\d{2}h\d{2} - \d{2}h\d{2}', time_str):
        # You can calculate the midpoint or handle it as a range
        # For midpoint:
        start, end = time_str.split(' - ')
        start = re.sub(r'(\d{2})h(\d{2})', r'\1:\2', start)[:5]  # Return the first 5 characters
        end = re.sub(r'(\d{2})h(\d{2})', r'\1:\2', end)[:5]  # Return the first 5 characters
        return start
    
    return 'unknown'

# Apply the function to your DataFrame
df['Time'] = df['Time'].apply(clean_and_standardize_time)

# %%
df['Time'].unique()
# Out:
# array(['18:00', '14:00', '07:45', 'unknown', '17:00', '08:00', '15:00',
#        '08:15', '11:00', '10:30', '10:40', '16:50', '07:00', '09:30',
#        '21:50', '09:40', '17:35', '15:30', '07:30', '19:00', '20:00',
#        '16:00', '15:01', '12:00', '13:45', '23:30', '09:00', '14:30',
#        '18:30', '12:30', '16:30', '18:45', '06:00', '10:00', '10:44',
#        '13:19', '13:30', '10:45', '11:20', '11:45', '19:30', '08:30',
#        '15:45', '17:34', '17:10', '11:15', '08:50', '17:45', '13:00',
#        '10:20', '13:20', '02:00', '09:50', '11:30', '17:30', '10:43',
#        '15:15', '15:40', '19:05', '22:00', '16:20', '14:34', '15:25',
#        '14:55', '17:46', '15:49', '10:15', '18:15', '04:00', '14:50',
#        '13:50', '19:20', '10:25', '16:45', '15:52', '06:15', '14:40',
#        '19:45', '10:10', '08:45', '12:10', '18:05', '11:41', '12:25',
#        '17:51', '16:12', '12:45', '10:50', '14:15', '09:45', '06:45',
#        '05:00', '03:30', '06:30', '17:20', '16:40', '16:18', '11:10',
#        '17:50', '17:01', '09:57', '08:20', '17:58', '20:30', '15:19',
#        '10:55', '15:55', '23:00', '12:40', '13:55', '16:05', '14:10',
#        '15:20', '12:50', '14:45', '13:40', '13:24', '11:40', '08:10',
#        '15:56', '14:20', '07:56', '17:17', '16:35', '09:05', '07:15',
#        '07:20', '19:28', '12:38', '05:50', '15:50', '11:05', '05:45',
#        '13:25', '12:20', '13:26', '09:11', '12:15', '13:15', '18:20',
#        '15:35', '13:51', '08:05', '19:15', '10:35', '15:44', '21:00',
#        '09:35', '10:27', '10:16', '09:20', '12:05', '14:21', '18:50',
#        '15:53', '11:11', '13:42', '20:15', '12:39', '07:05', '13:05',
#        '11:50', '17:55', '22:30', '17:15', '16:10', '06:10', '16:15',
#        '07:08', '03:00', '12:02', '12:55', '16:14', '17:11', '00:30',
#        '14:37', '10:07', '13:53', '11:55', '13:23', '02:30', '08:40',
#        '11:56', '14:35', '07:50', '14:25', '13:34', '06:47', '20:45',
#        '18:40', '13:14', '13:06', '12:34', '11:53', '12:46', '12:48',
#        '17:42', '12:35', '11:57', '17:40', '11:25', '18:25', '10:28',
#        '09:15', '14:16', '09:55', '15:05', '11:48', '07:19', '13:37',
#        '11:06', '11:58', '11:51', '18:12', '07:10', '07:40', '12:33',
#        '15:06', '12:54', '16:55', '05:40', '21:30', '08:57', '08:35',
#        '10:22', '02:45', '18:10', '08:55', '06:50', '01:00', '07:32',
#        '03:45', '13:10', '19:35', '13:35', '01:32', '16:23', '19:10',
#        '16:25', '11:01', '19:55', '01:30', '05:30', '08:58', '01:50'],
#       dtype=object)

# %%
# just in case reset the index and the case number
df = df.reset_index(drop=True)

df['Case Number'] = [int(e) for e in range(1, len(df)+1)]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6299 entries, 0 to 6298
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6299 non-null   int64
#  1   Date                    6296 non-null   object
#  2   Year                    6170 non-null   Int64
#  3   Type                    6299 non-null   object
#  4   Country                 6299 non-null   object
#  5   Area                    6299 non-null   object
#  6   Location                6299 non-null   object
#  7   Activity                6299 non-null   object
#  8   Name                    6299 non-null   object
#  9   Sex                     6299 non-null   object
#  10  Age                     3410 non-null   Int64
#  11  Injury                  6299 non-null   object
#  12  Fatal (Y/N)             6299 non-null   object
#  13  Time                    6299 non-null   object
#  14  Species                 6299 non-null   object
#  15  Investigator or Source  6299 non-null   object
#  16  pdf                     6299 non-null   object
#  17  href                    6299 non-null   object
# dtypes: Int64(2), int64(1), object(15)
# memory usage: 6.9 MB

# %%
df.to_csv('../data/shark_attacks_clean.csv', index=False)
